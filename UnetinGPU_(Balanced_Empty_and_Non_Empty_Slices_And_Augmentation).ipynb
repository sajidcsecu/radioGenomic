# %% [markdown]
# <a href="https://colab.research.google.com/github/sajidcsecu/radioGenomic/blob/main/UnetinGPU_(Balanced_Empty_and_Non_Empty_Slices_And_Augmentation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is the Code for the Segmentation on Rider Dataset (LUNG1). The Code is worked on the 2D slices over GPU. The balanced sampler and the augmentation is used in the code...

# %% [markdown]
# # (1) Import Required Libraries

# %%
# !pip install SimpleITK
# !pip install pydicom===2.4.3
# !pip install pydicom-seg
# !pip install numpy==1.23.5
# Out:
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: pydicom===2.4.3 in /usr/local/lib/python3.11/dist-packages (2.4.3)
# Requirement already satisfied: pydicom-seg in /usr/local/lib/python3.11/dist-packages (0.4.1)
# Requirement already satisfied: SimpleITK>1.2.4 in /usr/local/lib/python3.11/dist-packages (from pydicom-seg) (2.4.1)
# Requirement already satisfied: jsonschema<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from pydicom-seg) (3.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from pydicom-seg) (1.23.5)
# Requirement already satisfied: pydicom>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from pydicom-seg) (2.4.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (25.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (0.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (75.2.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (1.17.0)
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.11/dist-packages (1.23.5)

# %% [markdown]
# # (2) Import required Libraries

# %%
import os
import random
import time
import csv
import numpy as np
import torch
import torch.nn as nn
import torch.optim.lr_scheduler as lr_scheduler
from torch.cuda.amp import GradScaler, autocast
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import (
    jaccard_score,
    f1_score,
    recall_score,
    precision_score,
    accuracy_score,
)
from tqdm import tqdm

import cv2
from typing import List
import torch.multiprocessing as mp
import h5py
from google.colab import drive
import torch.amp as amp
import pickle
from torch.utils.data import Sampler
import torchvision.transforms.functional as TF

# %% [markdown]
# # (3) Mount Google Drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # (4) Data Preperation

# %%
class JointTransform:
    def __init__(self, rotation_range=10, horizontal_flip=True, vertical_flip=True, intensity_shift=True):
        self.rotation_range = rotation_range
        self.horizontal_flip = horizontal_flip
        self.vertical_flip = vertical_flip
        self.intensity_shift = intensity_shift

    def __call__(self, ct, mask):
        # Random rotation
        angle = random.uniform(-self.rotation_range, self.rotation_range)
        ct = TF.rotate(ct, angle)
        mask = TF.rotate(mask, angle)

        # Random horizontal flip
        if self.horizontal_flip and random.random() > 0.5:
            ct = TF.hflip(ct)
            mask = TF.hflip(mask)

        # Random vertical flip
        if self.vertical_flip and random.random() > 0.5:
            ct = TF.vflip(ct)
            mask = TF.vflip(mask)

        # Random intensity shift for CT
        if self.intensity_shift:
            shift = random.uniform(-0.1, 0.1)
            ct = ct + shift
            ct = torch.clamp(ct, 0.0, 1.0)

        return ct, mask

# %%
class BalancedTumorSampler(Sampler):
    def __init__(self, dataset, tumor_ratio=0.5, shuffle=True, index_cache_path=None):
        self.dataset = dataset
        self.tumor_ratio = tumor_ratio
        self.shuffle = shuffle
        self.index_cache_path = index_cache_path

        self.tumor_indices = []
        self.non_tumor_indices = []

        if index_cache_path and os.path.exists(index_cache_path):
            print(f"📂 Loading cached indices from {index_cache_path}")
            with open(index_cache_path, 'rb') as f:
                cached = pickle.load(f)
                self.tumor_indices = cached['tumor']
                self.non_tumor_indices = cached['non_tumor']
            print(f"✅ Loaded: {len(self.tumor_indices)} tumor, {len(self.non_tumor_indices)} non-tumor")
        else:
            print("🛠️ Computing tumor/non-tumor indices...")
            self._prepare_indices()
            if index_cache_path:
                print(f"💾 Saving indices to {index_cache_path}")
                with open(index_cache_path, 'wb') as f:
                    pickle.dump({'tumor': self.tumor_indices, 'non_tumor': self.non_tumor_indices}, f)

    def _prepare_indices(self):
        for idx in range(len(self.dataset)):
            _, mask = self.dataset[idx]
            if mask.sum() > 0:
                self.tumor_indices.append(idx)
            else:
                self.non_tumor_indices.append(idx)

    def __iter__(self):
        if self.shuffle:
            random.shuffle(self.tumor_indices)
            random.shuffle(self.non_tumor_indices)

        total_samples = min(len(self.tumor_indices), len(self.non_tumor_indices)) * 2
        num_tumor = int(self.tumor_ratio * total_samples)
        num_non_tumor = total_samples - num_tumor

        selected_tumor = self.tumor_indices[:num_tumor]
        selected_non_tumor = self.non_tumor_indices[:num_non_tumor]

        combined = selected_tumor + selected_non_tumor
        if self.shuffle:
            random.shuffle(combined)

        return iter(combined)

    def __len__(self):
        return min(len(self.tumor_indices), len(self.non_tumor_indices)) * 2

# %%
class HDF5SegmentationDataset(Dataset):
    def __init__(self, hdf5_path, transform=None):
        self.hdf5_path = hdf5_path
        self.transform = transform
        self.patient_ids = []

        # Read only keys for indexing
        with h5py.File(self.hdf5_path, 'r') as f:
            self.patient_ids = list(f.keys())
            self.slice_indices = [(pid, i) for pid in self.patient_ids for i in range(f[pid]['ct'].shape[0])]

    def __len__(self):
        return len(self.slice_indices)

    def __getitem__(self, idx):
        pid, slice_idx = self.slice_indices[idx]

        with h5py.File(self.hdf5_path, 'r') as f:
            ct_slice = f[pid]['ct'][slice_idx]
            mask_slice = f[pid]['mask'][slice_idx]

        # Normalize CT to [0, 1]
        ct_slice = (ct_slice - np.min(ct_slice)) / (np.max(ct_slice) - np.min(ct_slice) + 1e-5)

        # Convert to torch tensors and add channel dim
        ct_tensor = torch.tensor(ct_slice, dtype=torch.float32).unsqueeze(0)
        mask_tensor = torch.tensor(mask_slice, dtype=torch.long).unsqueeze(0)

        if self.transform:
            ct_tensor, mask_tensor = self.transform(ct_tensor, mask_tensor)

        return ct_tensor, mask_tensor

# %% [markdown]
# # 2. Unet

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(inplace=True)
        )

    def forward(self, x):
        return self.conv(x)

class UpSample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2)

    def forward(self, x):
        return self.up(x)

class EncoderBlock(nn.Module):
    def __init__(self, in_channels, out_channels, dropout=0.1):
        super().__init__()
        self.conv = DoubleConv(in_channels, out_channels)
        self.pool = nn.MaxPool2d(2)
        self.dropout = nn.Dropout(p=dropout)

    def forward(self, x):
        x = self.conv(x)
        p = self.pool(x)
        return x, self.dropout(p)

class DecoderBlock(nn.Module):
    def __init__(self, in_channels, out_channels, dropout=0.1):
        super().__init__()
        self.up = UpSample(in_channels, out_channels)
        self.conv = DoubleConv(out_channels * 2, out_channels)
        self.dropout = nn.Dropout(p=dropout)

    def forward(self, x, skip):
        x = self.up(x)
        x = torch.cat([x, skip], dim=1)
        x = self.conv(x)
        return self.dropout(x)

class UNet(nn.Module):
    def __init__(self, in_channels, out_channels, dropout=0.5):
        super().__init__()
        self.e1 = EncoderBlock(in_channels, 64, dropout=dropout)
        self.e2 = EncoderBlock(64, 128, dropout=dropout)
        self.e3 = EncoderBlock(128, 256, dropout=dropout)
        self.e4 = EncoderBlock(256, 512, dropout=dropout)

        self.b = DoubleConv(512, 1024)
        self.dropout_bottleneck = nn.Dropout(p=dropout)

        self.d1 = DecoderBlock(1024, 512, dropout=dropout)
        self.d2 = DecoderBlock(512, 256, dropout=dropout)
        self.d3 = DecoderBlock(256, 128, dropout=dropout)
        self.d4 = DecoderBlock(128, 64, dropout=dropout)

        self.outputs = nn.Conv2d(64, out_channels, kernel_size=1)

    def forward(self, x):
        s1, p1 = self.e1(x)
        s2, p2 = self.e2(p1)
        s3, p3 = self.e3(p2)
        s4, p4 = self.e4(p3)

        b = self.b(p4)
        b = self.dropout_bottleneck(b)

        d1 = self.d1(b, s4)
        d2 = self.d2(d1, s3)
        d3 = self.d3(d2, s2)
        d4 = self.d4(d3, s1)

        return self.outputs(d4)

# if __name__ == "__main__":
#     # double_conv = DoubleConv(256, 256)
#     # print(double_conv)
#     device = "cuda" if torch.cuda.is_available() else "cpu"
#     input_image = torch.randn((1, 1, 512, 512), dtype=torch.float32)
#     model = UNet(1, 1).to(device)
#     input_image = input_image.to(device)
#     out = model(input_image)
#     print(out.shape)
#     print(device)
#     print(torch.cuda.is_available())

# %% [markdown]
# ## 2. Loss Function

# %%
class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6, epsilon=1e-8):
        super(DiceLoss, self).__init__()
        self.smooth = smooth
        self.epsilon = epsilon

    def forward(self, preds, targets):
        preds = torch.sigmoid(preds)
        preds = preds.view(-1)
        targets = targets.view(-1)
        intersection = (preds * targets).sum()
        dice_score = (2. * intersection + self.smooth) / (preds.sum() + targets.sum() + self.smooth + self.epsilon)
        return 1 - dice_score

class DiceBCELoss(nn.Module):
    def __init__(self, smooth=1e-6, epsilon=1e-8):
        super(DiceBCELoss, self).__init__()
        self.smooth = smooth
        self.epsilon = epsilon
        self.bce = nn.BCEWithLogitsLoss()

    def forward(self, preds, targets):
        preds = preds.view(-1)
        targets = targets.view(-1)
        intersection = (torch.sigmoid(preds) * targets).sum()
        dice_loss = 1 - (2. * intersection + self.smooth) / (torch.sigmoid(preds).sum() + targets.sum() + self.smooth + self.epsilon)
        bce_loss = self.bce(preds, targets)
        return bce_loss + dice_loss

# %% [markdown]
# # 3. Test

# %%
class UnetTest:
    def __init__(self, test_result_path: str,metrics_csv, device: torch.device):
        self.test_result_path = test_result_path
        self.device = device
        self.metrics_csv = metrics_csv

        os.makedirs(self.test_result_path, exist_ok=True)

        # Initialize CSV file with headers
        if not os.path.exists(self.metrics_csv):
            with open(self.metrics_csv, mode='w', newline='') as f:
                writer = csv.writer(f)
                writer.writerow(["SampleID", "Jaccard", "F1", "Recall", "Precision", "Accuracy", "Time"])

        print(f"Test results will be saved to: {self.test_result_path}")
        print(f"Using device: {self.device} (CUDA available: {torch.cuda.is_available()})")

    def calculate_metrics(self, y_true: torch.Tensor, y_pred: torch.Tensor) -> List[float]:
        # Apply sigmoid and threshold at 0.5
        y_pred = (y_pred > 0.5).float()

        # Move to CPU and convert to numpy
        y_true_np = y_true.detach().cpu().numpy().astype(bool).reshape(-1)
        y_pred_np = y_pred.detach().cpu().numpy().astype(bool).reshape(-1)

        # If ground truth is completely empty or prediction is empty, set zero_division=0 for clarity
        return [
            jaccard_score(y_true_np, y_pred_np, zero_division=0),
            f1_score(y_true_np, y_pred_np, zero_division=0),
            recall_score(y_true_np, y_pred_np, zero_division=0),
            precision_score(y_true_np, y_pred_np, zero_division=0),
            accuracy_score(y_true_np, y_pred_np)
        ]


    def save_result(self, image: torch.Tensor, org_mask: torch.Tensor, predicted_mask: torch.Tensor, sample_id: int) -> None:
        predicted_mask = (predicted_mask.detach().cpu().numpy().squeeze() > 0.5).astype(np.uint8) * 255
        org_mask = (org_mask.detach().cpu().numpy().squeeze() > 0.5).astype(np.uint8) * 255
        image = (image.detach().cpu().numpy().squeeze() * 255).astype(np.uint8)

        h, w = image.shape
        line = np.ones((h, 10), dtype=np.uint8) * 128
        cat_images = np.concatenate([image, line, org_mask, line, predicted_mask], axis=1)

        file_name = os.path.join(self.test_result_path, f"sample_{sample_id}.png")
        success = cv2.imwrite(file_name, cat_images)

        if success:
            print(f"✅ Saved: {file_name}")
        else:
            print(f"❌ Failed to save image: {file_name}")

    def append_metrics_to_csv(self, sample_id: int, metrics: List[float], elapsed_time: float) -> None:
        with open(self.metrics_csv, mode='a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([sample_id] + [f"{m:.4f}" for m in metrics] + [f"{elapsed_time:.4f}"])

    def test(self, model: torch.nn.Module, test_loader: torch.utils.data.DataLoader) -> None:
        model.eval()
        metrics_score = np.zeros(5)
        time_taken = []

        with torch.no_grad():
            for pid, (x, y) in enumerate(test_loader):
                # if (pid >=2):
                #   break
                x = x.to(self.device, dtype=torch.float32)
                y = y.to(self.device, dtype=torch.float32)

                start_time = time.time()
                y_pred = torch.sigmoid(model(x))
                elapsed_time = time.time() - start_time
                time_taken.append(elapsed_time)

                batch_metrics = self.calculate_metrics(y, y_pred)
                metrics_score += np.array(batch_metrics)

                for idx in range(x.size(0)):
                    sample_id = pid * x.size(0) + idx
                    self.save_result(x[idx], y[idx], y_pred[idx], sample_id)
                    self.append_metrics_to_csv(sample_id, batch_metrics, elapsed_time)

        num_batches = len(test_loader)
        avg_metrics = metrics_score / num_batches

        print(f"\n🧪 Total Batches in Test Set: {num_batches}")
        print(f"📊 Jaccard: {avg_metrics[0]:.4f} | F1: {avg_metrics[1]:.4f} | Recall: {avg_metrics[2]:.4f} | "
              f"Precision: {avg_metrics[3]:.4f} | Accuracy: {avg_metrics[4]:.4f}")
        print(f"⚡ FPS: {1 / np.mean(time_taken):.2f}")

# %% [markdown]
# # 4. Training

# %%
class EarlyStopping:
    def __init__(self, patience=10, verbose=True, min_delta=0, path='checkpoint.pt'):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.min_delta = min_delta
        self.path = path

    def __call__(self, val_loss, model, epoch=None, optimizer=None):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, epoch, optimizer)
        elif score < self.best_score + self.min_delta:
            self.counter += 1
            if self.verbose:
                print(f"⏳ EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, epoch, optimizer)
            self.counter = 0

        return self.early_stop

    def save_checkpoint(self, val_loss, model, epoch, optimizer):
        if self.verbose:
            print(f"✅ Valid loss improved. Saving model...")
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict() if optimizer else None,
            'val_loss': val_loss
        }
        torch.save(checkpoint, self.path)
        self.val_loss_min = val_loss


class UnetTrain:
    def __init__(self,
                 model_file: str,
                 loss_result_path: str,
                 lr: float,
                 num_epochs: int,
                 device: torch.device):

        self.model_file = model_file
        self.loss_result_path = loss_result_path
        self.lr = lr
        self.num_epochs = num_epochs
        self.device = device

        # For reproducibility
        self.seeding(42)

        print(f"🔧 Training initialized: lr={self.lr}, epochs={self.num_epochs}")
        print(f"📁 Model will be saved to: {self.model_file}")
        print(f"📁 Loss log will be saved to: {self.loss_result_path}")
        print(f"💻 Device in use: {self.device} (CUDA available: {torch.cuda.is_available()})")

    def seeding(self, seed):
        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        torch.cuda.manual_seed(seed)
        torch.backends.cudnn.deterministic = True

    def epoch_time(self, start_time, end_time):
        elapsed_time = end_time - start_time
        elapsed_mins = int(elapsed_time / 60)
        elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
        return elapsed_mins, elapsed_secs

    def train(self, model, loader, optimizer, loss_fn, device):
        scaler = amp.GradScaler()
        epoch_loss = 0.0
        model.train()

        for batch_idx, (x, y) in enumerate(loader):
            # if (batch_idx >=10):
            #       break
            x = x.to(device, dtype=torch.float32)
            y = y.to(device, dtype=torch.float32)

            optimizer.zero_grad()
            with amp.autocast(device_type=self.device.type):
                y_pred = model(x)
                loss = loss_fn(y_pred, y)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            epoch_loss += loss.item()

        return epoch_loss / len(loader)

    def evaluate(self, model, loader, loss_fn, device):
        epoch_loss = 0.0
        model.eval()

        with torch.no_grad():
            for batch_idx, (x, y) in enumerate(loader):
                # if (batch_idx >=2):
                #     break
                x = x.to(device, dtype=torch.float32)
                y = y.to(device, dtype=torch.float32)
                y_pred = model(x)
                loss = loss_fn(y_pred, y)
                epoch_loss += loss.item()

        return epoch_loss / len(loader)

    def execute(self, train_loader, valid_loader):
        model = UNet(in_channels=1, out_channels=1, dropout=0.3).to(self.device)
        optimizer = torch.optim.AdamW(model.parameters(), lr=self.lr, weight_decay=1e-5)
        scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
        loss_fn = DiceBCELoss()

        early_stopping = EarlyStopping(patience=10, min_delta=0.001, path=self.model_file)
        results = {"train_loss": [], "valid_loss": []}

        for epoch in tqdm(range(1, self.num_epochs + 1), desc="🏋️ Training"):
            start_time = time.time()

            train_loss = self.train(model, train_loader, optimizer, loss_fn, self.device)
            valid_loss = self.evaluate(model, valid_loader, loss_fn, self.device)
            scheduler.step()

            end_time = time.time()
            epoch_mins, epoch_secs = self.epoch_time(start_time, end_time)

            results["train_loss"].append(train_loss)
            results["valid_loss"].append(valid_loss)

            print(f"📅 Epoch {epoch:03d} | ⏱️ {epoch_mins}m {epoch_secs}s | 🔥 Train: {train_loss:.4f} | 🎯 Val: {valid_loss:.4f}")

            if early_stopping(valid_loss, model, epoch, optimizer):
                print("🛑 Early stopping triggered.")
                break

        # Save train/val loss history to CSV
        with open(self.loss_result_path, "w", newline="") as file:
            writer = csv.writer(file)
            writer.writerow(["Epoch"] + list(range(1, len(results["train_loss"]) + 1)))
            writer.writerow(["Train Loss"] + results["train_loss"])
            writer.writerow(["Valid Loss"] + results["valid_loss"])

# %%
def main():
    # Set working directory
    target_dir = "/content/drive/MyDrive/PhDwork/Segmentation"
    os.chdir(target_dir)
    print("📁 Current Directory:", os.getcwd())

    # Training configuration
    batch_size = 16
    num_epochs = 100
    lr = 1e-4
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    transformation = "OriginalCT_With_Empty_NonEmpty_slices_In_Train"

    # Define paths
    output_dir = os.path.join(".","results",f"Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation")
    os.makedirs(output_dir, exist_ok=True)
    loss_result_file = os.path.join(output_dir, "train_and_valid_loss_results.csv")
    model_file = os.path.join(output_dir, "model.pth")
    test_metrics_file = os.path.join(output_dir, "test_metrics.csv")
    test_result_path = os.path.join(output_dir, "test_outputs")
    os.makedirs(test_result_path, exist_ok=True)

    DATASET_DIR = f"./datasets/Datasets_{transformation}"
    train_path = os.path.join(DATASET_DIR, "train_dataset.hdf5")
    valid_path = os.path.join(DATASET_DIR, "valid_dataset.hdf5")
    test_path = os.path.join(DATASET_DIR, "test_dataset.hdf5")

    train_transform = JointTransform(
        rotation_range=10,
        horizontal_flip=True,
        vertical_flip=True,
        intensity_shift=True
    )

    print("📦 Loading datasets...")
    train_dataset = HDF5SegmentationDataset(train_path,transform=train_transform)
    valid_dataset = HDF5SegmentationDataset(valid_path,transform=None)
    test_dataset = HDF5SegmentationDataset(test_path,transform=None)

    sampler = BalancedTumorSampler(train_dataset,
                               tumor_ratio=0.5,
                               shuffle=True,
                               index_cache_path=f'{DATASET_DIR}/tumor_indices.pkl')


    train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=sampler,num_workers=0, pin_memory=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)
    test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

    print(f"✅ Dataset sizes — Train: {len(train_dataset)}, Valid: {len(valid_dataset)}, Test: {len(test_dataset)}")

    # Initialize and run training
    trainer = UnetTrain(
        model_file=model_file,
        loss_result_path=loss_result_file,
        lr=lr,
        num_epochs=num_epochs,
        device=device
    )

    trainer.execute(train_loader, valid_loader)

    # Load best model for testing
    model = UNet(in_channels=1, out_channels=1).to(device)
    checkpoint = torch.load(model_file, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])

    # Test and save metrics
    tester = UnetTest(test_result_path,test_metrics_file,device)
    tester.test(model, test_loader)


if __name__ == "__main__":
    mp.set_start_method('spawn')  # Required for some multiprocessing backends
    main()
# Out:
# 📁 Current Directory: /content/drive/MyDrive/PhDwork/Segmentation
# 📦 Loading datasets...
# 📂 Loading cached indices from ./datasets/Datasets_OriginalCT_With_Empty_NonEmpty_slices_In_Train/tumor_indices.pkl
# ✅ Loaded: 5858 tumor, 35476 non-tumor
# ✅ Dataset sizes — Train: 41334, Valid: 5141, Test: 4653
# 🔧 Training initialized: lr=0.0001, epochs=100
# 📁 Model will be saved to: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/model.pth
# 📁 Loss log will be saved to: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/train_and_valid_loss_results.csv
# 💻 Device in use: cuda (CUDA available: True)
# 🏋️ Training:   0%|          | 0/100 [00:00<?, ?it/s]
# 📅 Epoch 001 | ⏱️ 35m 17s | 🔥 Train: 1.2548 | 🎯 Val: 1.1296
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   1%|          | 1/100 [35:23<58:23:34, 2123.37s/it]
# 📅 Epoch 002 | ⏱️ 31m 7s | 🔥 Train: 1.0812 | 🎯 Val: 1.0675
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   2%|▏         | 2/100 [1:06:31<53:43:13, 1973.41s/it]
# 📅 Epoch 003 | ⏱️ 31m 16s | 🔥 Train: 0.9493 | 🎯 Val: 0.9708
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   3%|▎         | 3/100 [1:37:49<51:59:24, 1929.53s/it]
# 📅 Epoch 004 | ⏱️ 31m 17s | 🔥 Train: 0.7532 | 🎯 Val: 0.9234
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   4%|▍         | 4/100 [2:09:07<50:54:41, 1909.19s/it]
# 📅 Epoch 005 | ⏱️ 31m 14s | 🔥 Train: 0.5779 | 🎯 Val: 0.9143
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   5%|▌         | 5/100 [2:40:22<50:03:29, 1896.94s/it]
# 📅 Epoch 006 | ⏱️ 31m 9s | 🔥 Train: 0.4965 | 🎯 Val: 0.8980
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   6%|▌         | 6/100 [3:11:32<49:17:33, 1887.80s/it]
# 📅 Epoch 007 | ⏱️ 31m 3s | 🔥 Train: 0.4387 | 🎯 Val: 0.8852
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   7%|▋         | 7/100 [3:42:36<48:34:10, 1880.11s/it]
# 📅 Epoch 008 | ⏱️ 31m 8s | 🔥 Train: 0.4153 | 🎯 Val: 0.8827
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   8%|▊         | 8/100 [4:13:46<47:57:38, 1876.73s/it]
# 📅 Epoch 009 | ⏱️ 31m 7s | 🔥 Train: 0.3960 | 🎯 Val: 0.8785
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   9%|▉         | 9/100 [4:44:54<47:22:35, 1874.23s/it]
# 📅 Epoch 010 | ⏱️ 31m 7s | 🔥 Train: 0.3883 | 🎯 Val: 0.8773
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:  11%|█         | 11/100 [5:47:09<46:14:40, 1870.57s/it]
# 📅 Epoch 011 | ⏱️ 31m 6s | 🔥 Train: 0.4321 | 🎯 Val: 0.8842
# ⏳ EarlyStopping counter: 1 out of 10
# 🏋️ Training:  12%|█▏        | 12/100 [6:18:11<45:39:46, 1868.03s/it]
# 📅 Epoch 012 | ⏱️ 31m 2s | 🔥 Train: 0.4260 | 🎯 Val: 0.8915
# ⏳ EarlyStopping counter: 2 out of 10
# 🏋️ Training:  13%|█▎        | 13/100 [6:48:59<44:59:36, 1861.80s/it]
# 📅 Epoch 013 | ⏱️ 30m 47s | 🔥 Train: 0.4126 | 🎯 Val: 0.9000
# ⏳ EarlyStopping counter: 3 out of 10
# 🏋️ Training:  14%|█▍        | 14/100 [7:19:39<44:19:25, 1855.41s/it]
# 📅 Epoch 014 | ⏱️ 30m 40s | 🔥 Train: 0.4041 | 🎯 Val: 0.8779
# ⏳ EarlyStopping counter: 4 out of 10
# 🏋️ Training:  15%|█▌        | 15/100 [7:50:22<43:42:57, 1851.50s/it]
# 📅 Epoch 015 | ⏱️ 30m 42s | 🔥 Train: 0.3894 | 🎯 Val: 0.8801
# ⏳ EarlyStopping counter: 5 out of 10
# 🏋️ Training:  16%|█▌        | 16/100 [8:21:05<43:08:44, 1849.10s/it]
# 📅 Epoch 016 | ⏱️ 30m 43s | 🔥 Train: 0.3758 | 🎯 Val: 0.8834
# ⏳ EarlyStopping counter: 6 out of 10
# 🏋️ Training:  17%|█▋        | 17/100 [8:51:55<42:37:56, 1849.12s/it]
# 📅 Epoch 017 | ⏱️ 30m 49s | 🔥 Train: 0.3749 | 🎯 Val: 0.8869
# ⏳ EarlyStopping counter: 7 out of 10
# 🏋️ Training:  18%|█▊        | 18/100 [9:22:47<42:08:30, 1850.13s/it]
# 📅 Epoch 018 | ⏱️ 30m 52s | 🔥 Train: 0.3596 | 🎯 Val: 0.8814
# ⏳ EarlyStopping counter: 8 out of 10
# 🏋️ Training:  19%|█▉        | 19/100 [9:53:29<41:34:20, 1847.66s/it]
# 📅 Epoch 019 | ⏱️ 30m 41s | 🔥 Train: 0.3529 | 🎯 Val: 0.8803
# ⏳ EarlyStopping counter: 9 out of 10
# 🏋️ Training:  19%|█▉        | 19/100 [10:23:55<44:19:51, 1970.27s/it]
# 📅 Epoch 020 | ⏱️ 30m 25s | 🔥 Train: 0.3449 | 🎯 Val: 0.8789
# ⏳ EarlyStopping counter: 10 out of 10
# 🛑 Early stopping triggered.
# Test results will be saved to: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs
# Using device: cuda (CUDA available: True)
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_0.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_1.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_2.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_5.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_6.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_7.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_8.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_9.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_10.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_11.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_12.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_13.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_14.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_15.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_16.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_17.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_18.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_19.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_20.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_21.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_22.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_23.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_24.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_25.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_26.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_27.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_28.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_29.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_30.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_31.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_32.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_33.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_34.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_35.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_36.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_37.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_38.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_39.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_40.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_41.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_42.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_43.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_44.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_45.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_46.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_47.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_48.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_49.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_50.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_51.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_52.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_53.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_54.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_55.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_56.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_57.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_58.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_59.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_60.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_61.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_62.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_63.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_64.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_65.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_66.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_67.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_68.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_69.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_70.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_71.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_72.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_73.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_74.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_75.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_76.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_77.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_78.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_79.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_80.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_81.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_82.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_83.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_84.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_85.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_86.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_87.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_88.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_89.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_90.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_91.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_92.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_93.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_94.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_95.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_96.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_97.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_98.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_99.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_100.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_101.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_102.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_103.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_104.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_105.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_106.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_107.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_108.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_109.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_110.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_111.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_112.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_113.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_114.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_115.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_116.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_117.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_118.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_119.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_120.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_121.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_122.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_123.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_124.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_125.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_126.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_127.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_128.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_129.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_130.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_131.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_132.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_133.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_134.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_135.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_136.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_137.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_138.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_139.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_140.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_141.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_142.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_143.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_144.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_145.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_146.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_147.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_148.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_149.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_150.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_151.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_152.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_153.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_154.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_155.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_156.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_157.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_158.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_159.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_160.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_161.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_162.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_163.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_164.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_165.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_166.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_167.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_168.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_169.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_170.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_171.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_172.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_173.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_174.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_175.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_176.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_177.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_178.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_179.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_180.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_181.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_182.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_183.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_184.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_185.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_186.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_187.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_188.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_189.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_190.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_191.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_192.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_193.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_194.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_195.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_196.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_197.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_198.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_199.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_200.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_201.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_202.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_203.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_204.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_205.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_206.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_207.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_208.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_209.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_210.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_211.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_212.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_213.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_214.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_215.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_216.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_217.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_218.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_219.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_220.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_221.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_222.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_223.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_224.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_225.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_226.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_227.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_228.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_229.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_230.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_231.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_232.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_233.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_234.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_235.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_236.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_237.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_238.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_239.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_240.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_241.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_242.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_243.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_244.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_245.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_246.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_247.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_248.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_249.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_250.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_251.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_252.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_253.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_254.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_255.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_256.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_257.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_258.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_259.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_260.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_261.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_262.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_263.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_264.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_265.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_266.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_267.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_268.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_269.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_270.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_271.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_272.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_273.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_274.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_275.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_276.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_277.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_278.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_279.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_280.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_281.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_282.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_283.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_284.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_285.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_286.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_287.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_288.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_289.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_290.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_291.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_292.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_293.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_294.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_295.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_296.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_297.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_298.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_299.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_300.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_301.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_302.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_303.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_304.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_305.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_306.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_307.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_308.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_309.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_310.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_311.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_312.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_313.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_314.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_315.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_316.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_317.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_318.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_319.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_320.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_321.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_322.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_323.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_324.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_325.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_326.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_327.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_328.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_329.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_330.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_331.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_332.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_333.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_334.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_335.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_336.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_337.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_338.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_339.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_340.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_341.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_342.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_343.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_344.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_345.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_346.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_347.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_348.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_349.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_350.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_351.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_352.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_353.png
# ...
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4527.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4528.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4529.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4530.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4531.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4532.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4533.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4534.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4535.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4536.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4537.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4538.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4539.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4540.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4541.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4542.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4543.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4544.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4545.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4546.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4547.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4548.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4549.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4550.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4551.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4552.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4553.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4554.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4555.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4556.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4557.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4558.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4559.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4560.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4561.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4562.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4563.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4564.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4565.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4566.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4567.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4568.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4569.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4570.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4571.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4572.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4573.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4574.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4575.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4576.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4577.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4578.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4579.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4580.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4581.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4582.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4583.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4584.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4585.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4586.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4587.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4588.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4589.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4590.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4591.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4592.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4593.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4594.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4595.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4596.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4597.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4598.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4599.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4600.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4601.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4602.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4603.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4604.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4605.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4606.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4607.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4608.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4609.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4610.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4611.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4612.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4613.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4614.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4615.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4616.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4617.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4618.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4619.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4620.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4621.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4622.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4623.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4624.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4625.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4626.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4627.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4628.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4629.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4630.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4631.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4632.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4633.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4634.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4635.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4636.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4637.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4638.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_4639.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3770.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3771.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3772.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3773.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3774.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3775.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3776.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3777.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3778.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3779.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3780.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3781.png
# ✅ Saved: ./results/Results_OriginalCT_With_Balanced_Empty_NonEmpty_slices_In_Train_Augmentation/test_outputs/sample_3782.png
#
# 🧪 Total Batches in Test Set: 291
# 📊 Jaccard: 0.0998 | F1: 0.1274 | Recall: 0.1470 | Precision: 0.1368 | Accuracy: 0.9992
# ⚡ FPS: 208.63
