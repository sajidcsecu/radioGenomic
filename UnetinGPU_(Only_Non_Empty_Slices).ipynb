# %% [markdown]
# <a href="https://colab.research.google.com/github/sajidcsecu/radioGenomic/blob/main/UnetinGPU_(Only_Non_Empty_Slices).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is the Code for the Segmentation on Rider Dataset (LUNG1). The Code is worked on the 2D slices over GPU

# %% [markdown]
# # (1) Import Required Libraries

# %%
# !pip install SimpleITK
# !pip install pydicom===2.4.3
# !pip install pydicom-seg
# !pip install numpy==1.23.5
# Out:
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: pydicom===2.4.3 in /usr/local/lib/python3.11/dist-packages (2.4.3)
# Requirement already satisfied: pydicom-seg in /usr/local/lib/python3.11/dist-packages (0.4.1)
# Requirement already satisfied: SimpleITK>1.2.4 in /usr/local/lib/python3.11/dist-packages (from pydicom-seg) (2.4.1)
# Requirement already satisfied: jsonschema<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from pydicom-seg) (3.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from pydicom-seg) (1.23.5)
# Requirement already satisfied: pydicom>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from pydicom-seg) (2.4.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (25.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (0.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (75.2.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (1.17.0)
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.11/dist-packages (1.23.5)

# %% [markdown]
# # (2) Import required Libraries

# %%
import os
import random
import time
import csv
import numpy as np
import torch
import torch.nn as nn
import torch.optim.lr_scheduler as lr_scheduler
from torch.cuda.amp import GradScaler, autocast
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import (
    jaccard_score,
    f1_score,
    recall_score,
    precision_score,
    accuracy_score,
)
from tqdm import tqdm

import cv2
from typing import List
import torch.multiprocessing as mp
import h5py
from google.colab import drive
import torch.amp as amp

# %% [markdown]
# # (3) Mount Google Drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # (4) Data Preperation

# %%
class HDF5SegmentationDataset(Dataset):
    def __init__(self, hdf5_path, transform=None):
        self.hdf5_path = hdf5_path
        self.transform = transform
        self.patient_ids = []

        # Read only keys for indexing
        with h5py.File(self.hdf5_path, 'r') as f:
            self.patient_ids = list(f.keys())
            self.slice_indices = [(pid, i) for pid in self.patient_ids for i in range(f[pid]['ct'].shape[0])]

    def __len__(self):
        return len(self.slice_indices)

    def __getitem__(self, idx):
        pid, slice_idx = self.slice_indices[idx]

        with h5py.File(self.hdf5_path, 'r') as f:
            ct_slice = f[pid]['ct'][slice_idx]
            mask_slice = f[pid]['mask'][slice_idx]

        # Normalize CT to [0, 1]
        ct_slice = (ct_slice - np.min(ct_slice)) / (np.max(ct_slice) - np.min(ct_slice) + 1e-5)

        # Convert to torch tensors and add channel dim
        ct_tensor = torch.tensor(ct_slice, dtype=torch.float32).unsqueeze(0)
        mask_tensor = torch.tensor(mask_slice, dtype=torch.long).unsqueeze(0)

        if self.transform:
            ct_tensor, mask_tensor = self.transform(ct_tensor, mask_tensor)

        return ct_tensor, mask_tensor

# %% [markdown]
# # 2. Unet

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(inplace=True)
        )

    def forward(self, x):
        return self.conv(x)

class UpSample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2)

    def forward(self, x):
        return self.up(x)

class EncoderBlock(nn.Module):
    def __init__(self, in_channels, out_channels, dropout=0.1):
        super().__init__()
        self.conv = DoubleConv(in_channels, out_channels)
        self.pool = nn.MaxPool2d(2)
        self.dropout = nn.Dropout(p=dropout)

    def forward(self, x):
        x = self.conv(x)
        p = self.pool(x)
        return x, self.dropout(p)

class DecoderBlock(nn.Module):
    def __init__(self, in_channels, out_channels, dropout=0.1):
        super().__init__()
        self.up = UpSample(in_channels, out_channels)
        self.conv = DoubleConv(out_channels * 2, out_channels)
        self.dropout = nn.Dropout(p=dropout)

    def forward(self, x, skip):
        x = self.up(x)
        x = torch.cat([x, skip], dim=1)
        x = self.conv(x)
        return self.dropout(x)

class UNet(nn.Module):
    def __init__(self, in_channels, out_channels, dropout=0.5):
        super().__init__()
        self.e1 = EncoderBlock(in_channels, 64, dropout=dropout)
        self.e2 = EncoderBlock(64, 128, dropout=dropout)
        self.e3 = EncoderBlock(128, 256, dropout=dropout)
        self.e4 = EncoderBlock(256, 512, dropout=dropout)

        self.b = DoubleConv(512, 1024)
        self.dropout_bottleneck = nn.Dropout(p=dropout)

        self.d1 = DecoderBlock(1024, 512, dropout=dropout)
        self.d2 = DecoderBlock(512, 256, dropout=dropout)
        self.d3 = DecoderBlock(256, 128, dropout=dropout)
        self.d4 = DecoderBlock(128, 64, dropout=dropout)

        self.outputs = nn.Conv2d(64, out_channels, kernel_size=1)

    def forward(self, x):
        s1, p1 = self.e1(x)
        s2, p2 = self.e2(p1)
        s3, p3 = self.e3(p2)
        s4, p4 = self.e4(p3)

        b = self.b(p4)
        b = self.dropout_bottleneck(b)

        d1 = self.d1(b, s4)
        d2 = self.d2(d1, s3)
        d3 = self.d3(d2, s2)
        d4 = self.d4(d3, s1)

        return self.outputs(d4)

# if __name__ == "__main__":
#     # double_conv = DoubleConv(256, 256)
#     # print(double_conv)
#     device = "cuda" if torch.cuda.is_available() else "cpu"
#     input_image = torch.randn((1, 1, 512, 512), dtype=torch.float32)
#     model = UNet(1, 1).to(device)
#     input_image = input_image.to(device)
#     out = model(input_image)
#     print(out.shape)
#     print(device)
#     print(torch.cuda.is_available())

# %% [markdown]
# ## 2. Loss Function

# %%
class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6, epsilon=1e-8):
        super(DiceLoss, self).__init__()
        self.smooth = smooth
        self.epsilon = epsilon

    def forward(self, preds, targets):
        preds = torch.sigmoid(preds)
        preds = preds.view(-1)
        targets = targets.view(-1)
        intersection = (preds * targets).sum()
        dice_score = (2. * intersection + self.smooth) / (preds.sum() + targets.sum() + self.smooth + self.epsilon)
        return 1 - dice_score

class DiceBCELoss(nn.Module):
    def __init__(self, smooth=1e-6, epsilon=1e-8):
        super(DiceBCELoss, self).__init__()
        self.smooth = smooth
        self.epsilon = epsilon
        self.bce = nn.BCEWithLogitsLoss()

    def forward(self, preds, targets):
        preds = preds.view(-1)
        targets = targets.view(-1)
        intersection = (torch.sigmoid(preds) * targets).sum()
        dice_loss = 1 - (2. * intersection + self.smooth) / (torch.sigmoid(preds).sum() + targets.sum() + self.smooth + self.epsilon)
        bce_loss = self.bce(preds, targets)
        return bce_loss + dice_loss

# %% [markdown]
# # 3. Test

# %%
class UnetTest:
    def __init__(self, test_result_path: str,metrics_csv, device: torch.device):
        self.test_result_path = test_result_path
        self.device = device
        self.metrics_csv = metrics_csv

        os.makedirs(self.test_result_path, exist_ok=True)

        # Initialize CSV file with headers
        if not os.path.exists(self.metrics_csv):
            with open(self.metrics_csv, mode='w', newline='') as f:
                writer = csv.writer(f)
                writer.writerow(["SampleID", "Jaccard", "F1", "Recall", "Precision", "Accuracy", "Time"])

        print(f"Test results will be saved to: {self.test_result_path}")
        print(f"Using device: {self.device} (CUDA available: {torch.cuda.is_available()})")

    def calculate_metrics(self, y_true: torch.Tensor, y_pred: torch.Tensor) -> List[float]:
        # Apply sigmoid and threshold at 0.5
        y_pred = (y_pred > 0.5).float()

        # Move to CPU and convert to numpy
        y_true_np = y_true.detach().cpu().numpy().astype(bool).reshape(-1)
        y_pred_np = y_pred.detach().cpu().numpy().astype(bool).reshape(-1)

        # If ground truth is completely empty or prediction is empty, set zero_division=0 for clarity
        return [
            jaccard_score(y_true_np, y_pred_np, zero_division=0),
            f1_score(y_true_np, y_pred_np, zero_division=0),
            recall_score(y_true_np, y_pred_np, zero_division=0),
            precision_score(y_true_np, y_pred_np, zero_division=0),
            accuracy_score(y_true_np, y_pred_np)
        ]


    def save_result(self, image: torch.Tensor, org_mask: torch.Tensor, predicted_mask: torch.Tensor, sample_id: int) -> None:
        predicted_mask = (predicted_mask.detach().cpu().numpy().squeeze() > 0.5).astype(np.uint8) * 255
        org_mask = (org_mask.detach().cpu().numpy().squeeze() > 0.5).astype(np.uint8) * 255
        image = (image.detach().cpu().numpy().squeeze() * 255).astype(np.uint8)

        h, w = image.shape
        line = np.ones((h, 10), dtype=np.uint8) * 128
        cat_images = np.concatenate([image, line, org_mask, line, predicted_mask], axis=1)

        file_name = os.path.join(self.test_result_path, f"sample_{sample_id}.png")
        success = cv2.imwrite(file_name, cat_images)

        if success:
            print(f"✅ Saved: {file_name}")
        else:
            print(f"❌ Failed to save image: {file_name}")

    def append_metrics_to_csv(self, sample_id: int, metrics: List[float], elapsed_time: float) -> None:
        with open(self.metrics_csv, mode='a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([sample_id] + [f"{m:.4f}" for m in metrics] + [f"{elapsed_time:.4f}"])

    def test(self, model: torch.nn.Module, test_loader: torch.utils.data.DataLoader) -> None:
        model.eval()
        metrics_score = np.zeros(5)
        time_taken = []

        with torch.no_grad():
            for pid, (x, y) in enumerate(test_loader):
                # if (pid >=2):
                #   break
                x = x.to(self.device, dtype=torch.float32)
                y = y.to(self.device, dtype=torch.float32)

                start_time = time.time()
                y_pred = torch.sigmoid(model(x))
                elapsed_time = time.time() - start_time
                time_taken.append(elapsed_time)

                batch_metrics = self.calculate_metrics(y, y_pred)
                metrics_score += np.array(batch_metrics)

                for idx in range(x.size(0)):
                    sample_id = pid * x.size(0) + idx
                    self.save_result(x[idx], y[idx], y_pred[idx], sample_id)
                    self.append_metrics_to_csv(sample_id, batch_metrics, elapsed_time)

        num_batches = len(test_loader)
        avg_metrics = metrics_score / num_batches

        print(f"\n🧪 Total Batches in Test Set: {num_batches}")
        print(f"📊 Jaccard: {avg_metrics[0]:.4f} | F1: {avg_metrics[1]:.4f} | Recall: {avg_metrics[2]:.4f} | "
              f"Precision: {avg_metrics[3]:.4f} | Accuracy: {avg_metrics[4]:.4f}")
        print(f"⚡ FPS: {1 / np.mean(time_taken):.2f}")

# %% [markdown]
# # 4. Training

# %%
class EarlyStopping:
    def __init__(self, patience=10, verbose=True, min_delta=0, path='checkpoint.pt'):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.min_delta = min_delta
        self.path = path

    def __call__(self, val_loss, model, epoch=None, optimizer=None):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, epoch, optimizer)
        elif score < self.best_score + self.min_delta:
            self.counter += 1
            if self.verbose:
                print(f"⏳ EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, epoch, optimizer)
            self.counter = 0

        return self.early_stop

    def save_checkpoint(self, val_loss, model, epoch, optimizer):
        if self.verbose:
            print(f"✅ Valid loss improved. Saving model...")
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict() if optimizer else None,
            'val_loss': val_loss
        }
        torch.save(checkpoint, self.path)
        self.val_loss_min = val_loss


class UnetTrain:
    def __init__(self,
                 model_file: str,
                 loss_result_path: str,
                 lr: float,
                 num_epochs: int,
                 device: torch.device):

        self.model_file = model_file
        self.loss_result_path = loss_result_path
        self.lr = lr
        self.num_epochs = num_epochs
        self.device = device

        # For reproducibility
        self.seeding(42)

        print(f"🔧 Training initialized: lr={self.lr}, epochs={self.num_epochs}")
        print(f"📁 Model will be saved to: {self.model_file}")
        print(f"📁 Loss log will be saved to: {self.loss_result_path}")
        print(f"💻 Device in use: {self.device} (CUDA available: {torch.cuda.is_available()})")

    def seeding(self, seed):
        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        torch.cuda.manual_seed(seed)
        torch.backends.cudnn.deterministic = True

    def epoch_time(self, start_time, end_time):
        elapsed_time = end_time - start_time
        elapsed_mins = int(elapsed_time / 60)
        elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
        return elapsed_mins, elapsed_secs

    def train(self, model, loader, optimizer, loss_fn, device):
        scaler = amp.GradScaler()
        epoch_loss = 0.0
        model.train()

        for batch_idx, (x, y) in enumerate(loader):
            # if (batch_idx >=10):
            #       break
            x = x.to(device, dtype=torch.float32)
            y = y.to(device, dtype=torch.float32)

            optimizer.zero_grad()
            with amp.autocast(device_type=self.device.type):
                y_pred = model(x)
                loss = loss_fn(y_pred, y)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            epoch_loss += loss.item()

        return epoch_loss / len(loader)

    def evaluate(self, model, loader, loss_fn, device):
        epoch_loss = 0.0
        model.eval()

        with torch.no_grad():
            for batch_idx, (x, y) in enumerate(loader):
                # if (batch_idx >=2):
                #     break
                x = x.to(device, dtype=torch.float32)
                y = y.to(device, dtype=torch.float32)
                y_pred = model(x)
                loss = loss_fn(y_pred, y)
                epoch_loss += loss.item()

        return epoch_loss / len(loader)

    def execute(self, train_loader, valid_loader):
        model = UNet(in_channels=1, out_channels=1, dropout=0.3).to(self.device)
        optimizer = torch.optim.AdamW(model.parameters(), lr=self.lr, weight_decay=1e-5)
        scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
        loss_fn = DiceBCELoss()

        early_stopping = EarlyStopping(patience=10, min_delta=0.001, path=self.model_file)
        results = {"train_loss": [], "valid_loss": []}

        for epoch in tqdm(range(1, self.num_epochs + 1), desc="🏋️ Training"):
            start_time = time.time()

            train_loss = self.train(model, train_loader, optimizer, loss_fn, self.device)
            valid_loss = self.evaluate(model, valid_loader, loss_fn, self.device)
            scheduler.step()

            end_time = time.time()
            epoch_mins, epoch_secs = self.epoch_time(start_time, end_time)

            results["train_loss"].append(train_loss)
            results["valid_loss"].append(valid_loss)

            print(f"📅 Epoch {epoch:03d} | ⏱️ {epoch_mins}m {epoch_secs}s | 🔥 Train: {train_loss:.4f} | 🎯 Val: {valid_loss:.4f}")

            if early_stopping(valid_loss, model, epoch, optimizer):
                print("🛑 Early stopping triggered.")
                break

        # Save train/val loss history to CSV
        with open(self.loss_result_path, "w", newline="") as file:
            writer = csv.writer(file)
            writer.writerow(["Epoch"] + list(range(1, len(results["train_loss"]) + 1)))
            writer.writerow(["Train Loss"] + results["train_loss"])
            writer.writerow(["Valid Loss"] + results["valid_loss"])

# %%
def main():
    # Set working directory
    target_dir = "/content/drive/MyDrive/PhDwork/Segmentation"
    os.chdir(target_dir)
    print("📁 Current Directory:", os.getcwd())

    # Training configuration
    batch_size = 16
    num_epochs = 100
    lr = 1e-4
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    transformation = "OriginalCT_Only_Non_Empty_slices"

    # Define paths
    output_dir = os.path.join(".","results",f"Results_{transformation}")
    os.makedirs(output_dir, exist_ok=True)
    loss_result_file = os.path.join(output_dir, "train_and_valid_loss_results.csv")
    model_file = os.path.join(output_dir, "model.pth")
    test_metrics_file = os.path.join(output_dir, "test_metrics.csv")
    test_result_path = os.path.join(output_dir, "test_outputs")
    os.makedirs(test_result_path, exist_ok=True)

    DATASET_DIR = f"./datasets/Datasets_{transformation}"
    train_path = os.path.join(DATASET_DIR, "train_dataset.hdf5")
    valid_path = os.path.join(DATASET_DIR, "valid_dataset.hdf5")
    test_path = os.path.join(DATASET_DIR, "test_dataset.hdf5")

    print("📦 Loading datasets...")
    train_dataset = HDF5SegmentationDataset(train_path)
    valid_dataset = HDF5SegmentationDataset(valid_path)
    test_dataset = HDF5SegmentationDataset(test_path)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)
    test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

    print(f"✅ Dataset sizes — Train: {len(train_dataset)}, Valid: {len(valid_dataset)}, Test: {len(test_dataset)}")

    # Initialize and run training
    trainer = UnetTrain(
        model_file=model_file,
        loss_result_path=loss_result_file,
        lr=lr,
        num_epochs=num_epochs,
        device=device
    )

    trainer.execute(train_loader, valid_loader)

    # Load best model for testing
    model = UNet(in_channels=1, out_channels=1).to(device)
    checkpoint = torch.load(model_file, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])

    # Test and save metrics
    tester = UnetTest(test_result_path,test_metrics_file,device)
    tester.test(model, test_loader)


if __name__ == "__main__":
    mp.set_start_method('spawn')  # Required for some multiprocessing backends
    main()
# Out:
# 📁 Current Directory: /content/drive/MyDrive/PhDwork/Segmentation
# 📦 Loading datasets...
# ✅ Dataset sizes — Train: 5858, Valid: 5141, Test: 4653
# 🔧 Training initialized: lr=0.0001, epochs=100
# 📁 Model will be saved to: ./results/Results_OriginalCT_Only_Non_Empty_slices/model.pth
# 📁 Loss log will be saved to: ./results/Results_OriginalCT_Only_Non_Empty_slices/train_and_valid_loss_results.csv
# 💻 Device in use: cuda (CUDA available: True)
# 🏋️ Training:   0%|          | 0/100 [00:00<?, ?it/s]
# 📅 Epoch 001 | ⏱️ 18m 23s | 🔥 Train: 1.3226 | 🎯 Val: 1.2223
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   1%|          | 1/100 [18:24<30:22:45, 1104.70s/it]
# 📅 Epoch 002 | ⏱️ 15m 20s | 🔥 Train: 1.1644 | 🎯 Val: 1.1486
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   2%|▏         | 2/100 [33:45<27:08:02, 996.76s/it]
# 📅 Epoch 003 | ⏱️ 15m 29s | 🔥 Train: 1.0500 | 🎯 Val: 1.0671
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   3%|▎         | 3/100 [49:15<26:02:09, 966.29s/it]
# 📅 Epoch 004 | ⏱️ 15m 28s | 🔥 Train: 0.9438 | 🎯 Val: 1.0242
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   4%|▍         | 4/100 [1:04:45<25:22:40, 951.67s/it]
# 📅 Epoch 005 | ⏱️ 15m 28s | 🔥 Train: 0.8351 | 🎯 Val: 0.9902
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   5%|▌         | 5/100 [1:20:14<24:53:59, 943.57s/it]
# 📅 Epoch 006 | ⏱️ 15m 27s | 🔥 Train: 0.7187 | 🎯 Val: 0.9705
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   6%|▌         | 6/100 [1:35:43<24:30:23, 938.55s/it]
# 📅 Epoch 007 | ⏱️ 15m 30s | 🔥 Train: 0.6207 | 🎯 Val: 0.9501
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   7%|▋         | 7/100 [1:51:14<24:11:04, 936.18s/it]
# 📅 Epoch 008 | ⏱️ 15m 28s | 🔥 Train: 0.5484 | 🎯 Val: 0.9471
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   8%|▊         | 8/100 [2:06:43<23:52:03, 933.95s/it]
# 📅 Epoch 009 | ⏱️ 15m 28s | 🔥 Train: 0.5112 | 🎯 Val: 0.9438
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:   9%|▉         | 9/100 [2:22:13<23:34:23, 932.56s/it]
# 📅 Epoch 010 | ⏱️ 15m 28s | 🔥 Train: 0.4932 | 🎯 Val: 0.9399
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:  10%|█         | 10/100 [2:37:42<23:17:16, 931.52s/it]
# 📅 Epoch 011 | ⏱️ 15m 36s | 🔥 Train: 0.4968 | 🎯 Val: 0.9157
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:  11%|█         | 11/100 [2:53:19<23:04:29, 933.36s/it]
# 📅 Epoch 012 | ⏱️ 15m 36s | 🔥 Train: 0.4001 | 🎯 Val: 0.9078
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:  12%|█▏        | 12/100 [3:08:57<22:50:46, 934.62s/it]
# 📅 Epoch 013 | ⏱️ 15m 37s | 🔥 Train: 0.3356 | 🎯 Val: 0.9023
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:  13%|█▎        | 13/100 [3:24:35<22:36:47, 935.71s/it]
# 📅 Epoch 014 | ⏱️ 15m 36s | 🔥 Train: 0.2900 | 🎯 Val: 0.8955
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:  14%|█▍        | 14/100 [3:40:13<22:21:56, 936.24s/it]
# 📅 Epoch 015 | ⏱️ 15m 37s | 🔥 Train: 0.2705 | 🎯 Val: 0.8893
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:  16%|█▌        | 16/100 [4:11:30<21:52:30, 937.51s/it]
# 📅 Epoch 016 | ⏱️ 15m 39s | 🔥 Train: 0.2384 | 🎯 Val: 0.8897
# ⏳ EarlyStopping counter: 1 out of 10
# 🏋️ Training:  17%|█▋        | 17/100 [4:27:04<21:35:24, 936.44s/it]
# 📅 Epoch 017 | ⏱️ 15m 33s | 🔥 Train: 0.2257 | 🎯 Val: 0.8907
# ⏳ EarlyStopping counter: 2 out of 10
# 🏋️ Training:  18%|█▊        | 18/100 [4:42:38<21:18:57, 935.82s/it]
# 📅 Epoch 018 | ⏱️ 15m 34s | 🔥 Train: 0.2094 | 🎯 Val: 0.8905
# ⏳ EarlyStopping counter: 3 out of 10
# 📅 Epoch 019 | ⏱️ 15m 30s | 🔥 Train: 0.1936 | 🎯 Val: 0.8813
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:  19%|█▉        | 19/100 [4:58:09<21:01:23, 934.36s/it]
# 📅 Epoch 020 | ⏱️ 15m 40s | 🔥 Train: 0.1831 | 🎯 Val: 0.8765
# ✅ Valid loss improved. Saving model...
# 🏋️ Training:  21%|██        | 21/100 [5:29:39<20:37:45, 940.06s/it]
# 📅 Epoch 021 | ⏱️ 15m 48s | 🔥 Train: 0.1742 | 🎯 Val: 0.8820
# ⏳ EarlyStopping counter: 1 out of 10
# 🏋️ Training:  22%|██▏       | 22/100 [5:45:16<20:21:02, 939.26s/it]
# 📅 Epoch 022 | ⏱️ 15m 37s | 🔥 Train: 0.1632 | 🎯 Val: 0.8818
# ⏳ EarlyStopping counter: 2 out of 10
# 🏋️ Training:  23%|██▎       | 23/100 [6:00:59<20:06:39, 940.26s/it]
# 📅 Epoch 023 | ⏱️ 15m 42s | 🔥 Train: 0.1547 | 🎯 Val: 0.8834
# ⏳ EarlyStopping counter: 3 out of 10
# 🏋️ Training:  24%|██▍       | 24/100 [6:16:32<19:48:08, 938.00s/it]
# 📅 Epoch 024 | ⏱️ 15m 32s | 🔥 Train: 0.1486 | 🎯 Val: 0.8802
# ⏳ EarlyStopping counter: 4 out of 10
# 🏋️ Training:  25%|██▌       | 25/100 [6:32:02<19:29:41, 935.75s/it]
# 📅 Epoch 025 | ⏱️ 15m 30s | 🔥 Train: 0.1429 | 🎯 Val: 0.8806
# ⏳ EarlyStopping counter: 5 out of 10
# 🏋️ Training:  26%|██▌       | 26/100 [6:47:33<19:12:24, 934.38s/it]
# 📅 Epoch 026 | ⏱️ 15m 31s | 🔥 Train: 0.1368 | 🎯 Val: 0.8849
# ⏳ EarlyStopping counter: 6 out of 10
# 🏋️ Training:  27%|██▋       | 27/100 [7:03:03<18:55:00, 932.89s/it]
# 📅 Epoch 027 | ⏱️ 15m 29s | 🔥 Train: 0.1330 | 🎯 Val: 0.8794
# ⏳ EarlyStopping counter: 7 out of 10
# 🏋️ Training:  28%|██▊       | 28/100 [7:18:32<18:38:12, 931.85s/it]
# 📅 Epoch 028 | ⏱️ 15m 29s | 🔥 Train: 0.1296 | 🎯 Val: 0.8813
# ⏳ EarlyStopping counter: 8 out of 10
# 🏋️ Training:  29%|██▉       | 29/100 [7:34:14<18:26:04, 934.71s/it]
# 📅 Epoch 029 | ⏱️ 15m 41s | 🔥 Train: 0.1285 | 🎯 Val: 0.8807
# ⏳ EarlyStopping counter: 9 out of 10
# 🏋️ Training:  29%|██▉       | 29/100 [7:49:49<19:10:14, 972.04s/it]
# 📅 Epoch 030 | ⏱️ 15m 34s | 🔥 Train: 0.1270 | 🎯 Val: 0.8810
# ⏳ EarlyStopping counter: 10 out of 10
# 🛑 Early stopping triggered.
# Test results will be saved to: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs
# Using device: cuda (CUDA available: True)
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_0.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_1.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_2.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_5.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_6.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_7.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_8.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_9.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_10.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_11.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_12.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_13.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_14.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_15.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_16.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_17.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_18.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_19.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_20.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_21.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_22.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_23.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_24.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_25.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_26.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_27.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_28.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_29.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_30.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_31.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_32.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_33.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_34.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_35.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_36.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_37.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_38.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_39.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_40.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_41.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_42.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_43.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_44.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_45.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_46.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_47.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_48.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_49.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_50.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_51.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_52.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_53.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_54.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_55.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_56.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_57.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_58.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_59.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_60.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_61.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_62.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_63.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_64.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_65.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_66.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_67.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_68.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_69.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_70.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_71.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_72.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_73.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_74.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_75.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_76.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_77.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_78.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_79.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_80.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_81.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_82.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_83.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_84.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_85.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_86.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_87.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_88.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_89.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_90.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_91.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_92.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_93.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_94.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_95.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_96.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_97.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_98.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_99.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_100.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_101.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_102.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_103.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_104.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_105.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_106.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_107.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_108.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_109.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_110.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_111.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_112.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_113.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_114.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_115.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_116.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_117.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_118.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_119.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_120.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_121.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_122.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_123.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_124.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_125.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_126.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_127.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_128.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_129.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_130.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_131.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_132.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_133.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_134.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_135.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_136.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_137.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_138.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_139.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_140.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_141.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_142.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_143.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_144.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_145.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_146.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_147.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_148.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_149.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_150.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_151.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_152.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_153.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_154.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_155.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_156.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_157.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_158.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_159.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_160.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_161.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_162.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_163.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_164.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_165.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_166.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_167.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_168.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_169.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_170.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_171.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_172.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_173.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_174.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_175.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_176.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_177.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_178.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_179.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_180.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_181.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_182.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_183.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_184.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_185.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_186.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_187.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_188.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_189.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_190.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_191.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_192.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_193.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_194.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_195.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_196.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_197.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_198.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_199.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_200.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_201.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_202.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_203.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_204.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_205.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_206.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_207.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_208.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_209.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_210.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_211.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_212.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_213.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_214.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_215.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_216.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_217.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_218.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_219.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_220.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_221.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_222.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_223.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_224.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_225.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_226.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_227.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_228.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_229.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_230.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_231.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_232.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_233.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_234.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_235.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_236.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_237.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_238.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_239.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_240.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_241.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_242.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_243.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_244.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_245.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_246.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_247.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_248.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_249.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_250.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_251.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_252.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_253.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_254.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_255.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_256.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_257.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_258.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_259.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_260.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_261.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_262.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_263.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_264.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_265.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_266.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_267.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_268.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_269.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_270.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_271.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_272.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_273.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_274.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_275.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_276.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_277.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_278.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_279.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_280.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_281.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_282.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_283.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_284.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_285.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_286.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_287.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_288.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_289.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_290.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_291.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_292.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_293.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_294.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_295.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_296.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_297.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_298.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_299.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_300.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_301.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_302.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_303.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_304.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_305.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_306.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_307.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_308.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_309.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_310.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_311.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_312.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_313.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_314.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_315.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_316.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_317.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_318.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_319.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_320.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_321.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_322.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_323.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_324.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_325.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_326.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_327.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_328.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_329.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_330.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_331.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_332.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_333.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_334.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_335.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_336.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_337.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_338.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_339.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_340.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_341.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_342.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_343.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_344.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_345.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_346.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_347.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_348.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_349.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_350.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_351.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_352.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_353.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_354.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_355.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_356.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_357.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_358.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_359.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_360.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_361.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_362.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_363.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_364.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_365.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_366.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_367.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_368.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_369.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_370.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_371.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_372.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_373.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_374.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_375.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_376.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_377.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_378.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_379.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_380.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_381.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_382.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_383.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_384.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_385.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_386.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_387.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_388.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_389.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_390.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_391.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_392.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_393.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_394.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_395.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_396.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_397.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_398.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_399.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_400.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_401.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_402.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_403.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_404.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_405.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_406.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_407.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_408.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_409.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_410.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_411.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_412.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_413.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_414.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_415.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_416.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_417.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_418.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_419.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_420.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_421.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_422.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_423.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_424.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_425.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_426.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_427.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_428.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_429.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_430.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_431.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_432.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_433.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_434.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_435.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_436.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_437.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_438.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_439.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_440.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_441.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_442.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_443.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_444.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_445.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_446.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_447.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_448.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_449.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_450.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_451.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_452.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_453.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_454.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_455.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_456.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_457.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_458.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_459.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_460.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_461.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_462.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_463.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_464.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_465.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_466.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_467.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_468.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_469.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_470.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_471.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_472.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_473.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_474.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_475.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_476.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_477.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_478.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_479.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_480.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_481.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_482.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_483.png
# ...
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4475.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4476.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4477.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4478.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4479.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4480.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4481.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4482.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4483.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4484.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4485.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4486.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4487.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4488.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4489.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4490.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4491.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4492.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4493.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4494.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4495.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4496.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4497.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4498.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4499.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4500.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4501.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4502.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4503.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4504.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4505.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4506.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4507.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4508.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4509.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4510.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4511.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4512.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4513.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4514.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4515.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4516.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4517.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4518.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4519.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4520.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4521.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4522.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4523.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4524.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4525.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4526.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4527.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4528.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4529.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4530.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4531.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4532.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4533.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4534.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4535.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4536.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4537.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4538.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4539.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4540.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4541.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4542.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4543.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4544.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4545.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4546.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4547.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4548.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4549.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4550.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4551.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4552.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4553.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4554.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4555.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4556.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4557.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4558.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4559.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4560.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4561.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4562.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4563.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4564.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4565.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4566.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4567.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4568.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4569.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4570.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4571.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4572.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4573.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4574.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4575.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4576.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4577.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4578.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4579.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4580.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4581.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4582.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4583.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4584.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4585.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4586.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4587.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4588.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4589.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4590.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4591.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4592.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4593.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4594.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4595.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4596.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4597.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4598.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4599.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4600.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4601.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4602.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4603.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4604.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4605.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4606.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4607.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4608.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4609.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4610.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4611.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4612.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4613.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4614.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4615.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4616.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4617.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4618.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4619.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4620.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4621.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4622.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4623.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4624.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4625.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4626.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4627.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4628.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4629.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4630.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4631.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4632.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4633.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4634.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4635.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4636.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4637.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4638.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_4639.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3770.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3771.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3772.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3773.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3774.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3775.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3776.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3777.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3778.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3779.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3780.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3781.png
# ✅ Saved: ./results/Results_OriginalCT_Only_Non_Empty_slices/test_outputs/sample_3782.png
#
# 🧪 Total Batches in Test Set: 291
# 📊 Jaccard: 0.1073 | F1: 0.1363 | Recall: 0.1544 | Precision: 0.1474 | Accuracy: 0.9991
# ⚡ FPS: 203.58

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from typing import List
import os
import csv


class LossPlotter:
    def __init__(self, csv_path: str):
        self.csv_path = Path(csv_path)
        self.data = self._load_data()

    def _load_data(self):
        if not self.csv_path.exists():
            raise FileNotFoundError(f"CSV file not found: {self.csv_path}")
        df = pd.read_csv(self.csv_path, index_col=0)  # Read row labels as index
        return df.transpose()  # Make rows into columns

    def plot(self, title: str = "Training and Validation Loss", save_path= None):
        plt.figure(figsize=(8, 5))
        plt.plot(self.data.index, self.data['Train Loss'], label='Train Loss', color='blue')
        plt.plot(self.data.index, self.data['Valid Loss'], label='Valid Loss', color='orange')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title(title)
        plt.legend()
        plt.grid(True)
        plt.tight_layout()

        if save_path:
            save_path = Path(save_path)
            save_path.parent.mkdir(parents=True, exist_ok=True)
            plt.savefig(save_path, format='pdf')
            print(f"[INFO] Loss plot saved to {save_path}")
        else:
            plt.show()

        plt.close()

if __name__ == "__main__":
    target_dir = "/content/drive/MyDrive/PhDwork/Segmentation"
    os.chdir(target_dir)
    loss_result_file = os.path.join(".","results",f"Results_OriginalCT_Only_Non_Empty_slices","train_and_valid_loss_results.csv")
    plotter = LossPlotter(loss_result_file)
    plotter.plot()
